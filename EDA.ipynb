# %%
# Importing required libraries
import pandas as pd
import functions as fun
import importlib as imp
pd.set_option('display.max_rows', None)
pd.options.display.float_format = "{: .3f}".format

import warnings
warnings.filterwarnings("ignore")

# Setting a default template for plotly
import plotly.io as pio
pio.templates.default = "plotly_dark"

# Setting a path to the directory
directory = ''

# %%
imp.reload(fun)
# Out:
# <module 'functions' from 'c:\\Users\\user\\OneDrive\\PD\\Диплом М\\real_estate_price_prediction\\functions.py'>

# %%
# Importing other variables for EDA
data = pd.read_parquet(directory + 'Data_for_models/final_eda.parquet').set_index('date')
target = pd.read_csv(directory + 'Data/metro_aggregates.csv').set_index('date')
fixes = {'\xa0': '', ' ': '', ',': ''}
for key in fixes:
    target['CHPI'] = target['CHPI'].str.replace(key, fixes[key])
target['CHPI'] = target['CHPI'].astype(int)
target.index = pd.to_datetime(target.index)
data = target.join(data).dropna()

# Plotting dynamics of the variables
fun.variables_dynamics(data)

# %%
# Linear and nonlinear correlations for main variables
fun.heatmap(data[data.columns[~data.columns.str.contains('week_logdyn')]])

# %%
# Stationarity and the level of chaos in the time series
fun.stationarity(data)
# Out:
#                          Variable  DF statistics  DF p-value  Lyapunov LE  \
# 0                            CHPI         -0.386       0.912        0.002
# 1                         KeyRate         -0.819       0.814        0.003
# 2                             CPI          2.961       1.000        0.004
# 3                             VIX         -3.346       0.013       -0.009
# 4                             PPI         -0.370       0.915        0.014
# 5                  MortgageRate30         -0.531       0.886        0.011
# 6                     Electricity          0.704       0.990        0.008
# 7                           Water          2.178       0.999        0.000
# 8                         Plywood         -1.458       0.554        0.022
# 9                           Steel         -2.224       0.198        0.009
# 10                          Glass          2.377       0.999        0.003
# 11                       Concrete          2.901       1.000        0.002
# ...
